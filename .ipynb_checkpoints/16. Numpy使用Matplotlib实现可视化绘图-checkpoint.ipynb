# %% [markdown]
# ## Numpy使用Matplotlib实现可视化绘图
#
# 可以直接将Numpy的数组传给Matplotlib实现可视化绘图：
# 1. 曲线图
# 2. 饼图
# 3. 柱状图
# 4. 直方图

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. 绘制正弦曲线

# %%
x = np.linspace(-10, 10, 100)
x.shape
# Out:
# (100,)

# %%
y = np.sin(x)
y.shape
# Out:
# (100,)

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 2. 绘制饼图

# %%
# 数字array
arr = np.array([15, 30, 45, 10])

# %%
# 名字
labels = np.array(['Frogs', 'Hogs', 'Dogs', 'Logs'])

# %%
plt.pie(arr, labels=labels, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### 3. 柱状图

# %%
# 数字array
arr = np.array([15, 30, 45, 10])

# %%
# 数字名字
labels = np.array(['Frogs', 'Hogs', 'Dogs', 'Logs'])

# %%
plt.bar(labels, arr)
plt.show()

# %% [markdown]
# ### 4. 直方图

# %%
# 采样得到正态分布的随机数10000个
mu, sigma = 2, 1
arr = np.random.normal(mu, sigma, 10000)

# %%
arr
# Out:
# array([ 3.38361979,  1.21464864,  2.31865103, ...,  1.85980346,
#        -0.39531567,  1.32741677])

# %%
plt.hist(arr, bins=100, density=1)
plt.show()
